# %% [markdown]
# <a href="https://colab.research.google.com/github/janjib/DataScienceLondonCompetition/blob/main/Project_1_Simple_Linear_Regression_on_Local_Chicken_Production_according_to_year.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib as pyplot
import pandas as pd

# %%
df = pd.read_csv("chicken_price_dataset.csv")
df.head()
# Out:
#    Year  Chicken Population (Number)  \
# 0  2000                    123841122
# 1  2001                    148990824
# 2  2002                    170395132
# 3  2003                    183345888
# 4  2004                    191655949
#
#    Local Production of Chicken Meat - Quantity (Tonne)  \
# 0                                             628558
# 1                                             674564
# 2                                             752787
# 3                                             756439
# 4                                             816191
#
#    Local Production of Chicken Meat - (RM Million)  \
# 0                                           2581.7
# 1                                           2696.7
# 2                                           3085.4
# 3                                           3321.2
# 4                                           3638.9
#
#    Imports of Chicken Meat - Quantity (Tonne)  \
# 0                                       35118
# ...

# %%
pd.isnull(df)
# Out:
#      Year  Chicken Population (Number)  \
# 0   False                        False
# 1   False                        False
# 2   False                        False
# 3   False                        False
# 4   False                        False
# 5   False                        False
# 6   False                        False
# 7   False                        False
# 8   False                        False
# 9   False                        False
# 10  False                        False
# 11  False                        False
# 12  False                        False
# 13  False                        False
# 14  False                        False
# 15  False                        False
# 16  False                        False
# 17  False                        False
# 18  False                        False
# 19  False                        False
#
#     Local Production of Chicken Meat - Quantity (Tonne)  \
# 0                                               False
# ...

# %%
dataset = df.iloc[:,[0,2]]
dataset.head()
# Out:
#    Year  Local Production of Chicken Meat - Quantity (Tonne)
# 0  2000                                             628558
# 1  2001                                             674564
# 2  2002                                             752787
# 3  2003                                             756439
# 4  2004                                             816191

# %%
x = dataset.iloc[:,:-1].values
x
# Out:
# array([[2000],
#        [2001],
#        [2002],
#        [2003],
#        [2004],
#        [2005],
#        [2006],
#        [2007],
#        [2008],
#        [2009],
#        [2010],
#        [2011],
#        [2012],
#        [2013],
#        [2014],
#        [2015],
#        [2016],
#        [2017],
#        [2018],
#        [2019]])

# %%
y = dataset.iloc[:,-1].values
y
# Out:
# array([ 628558,  674564,  752787,  756439,  816191,  862444,  911172,
#         968000, 1023062, 1057760, 1140128, 1174334, 1223188, 1297703,
#        1511763, 1551141, 1676246, 1598258, 1587539, 1589081])

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=0)

# %%
x_train
# Out:
# array([[2010],
#        [2017],
#        [2006],
#        [2013],
#        [2004],
#        [2002],
#        [2005],
#        [2014],
#        [2009],
#        [2007],
#        [2016],
#        [2011],
#        [2003],
#        [2000],
#        [2015],
#        [2012]])

# %%
y_train
# Out:
# array([1140128, 1598258,  911172, 1297703,  816191,  752787,  862444,
#        1511763, 1057760,  968000, 1676246, 1174334,  756439,  628558,
#        1551141, 1223188])

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
def predictor(year):
  prediction = regressor.predict([[year]])
  return f"The local production of chicken meat on {year} is {prediction}"

predictor(2012)
# Out:
# 'The local production of chicken meat on 2012 is [1304833.93632075]'
